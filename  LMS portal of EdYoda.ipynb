# %%
#welcome to LMS portal of EdYoda




class LMS:
    manager={}  #Class attributes(dict) to store the data
    students={} #Class attributes(dict) to store the data
    def _init_(self):
        self.today = 0
        self.start = 0
        self.end = 0
        self.status = 0
    def set_name(self,name):
        self.name=name
    def set_age(self,age):
        self.age = age
    def set_mobile(self,mobile):
        self.mobile=mobile
    def set_email(self,email):
        self.email=email
        
    def set_module(self,module):
        self.module=module
        #self.today=today
        self.get_status(module)
    def set_live_session(self,livesession):
        self.livesession = livesession
        self.get_session(livesession)
    def set_password(self,password):
        self.password=password
    def set_gender(self,gender)->str:
        self.gender=gender
    def get_session(self,livesession):
        if self.livesession is True:
            self.session = {1:"python",2:"java"}
            print(self.livesession)
        else:
            print("today no session")
    def set_period(self,start,end):
        self.startdate = start
        self.enddate = end
    def set_today(self,today):
        self.today=today
        self.get_status(today)
    def get_status(self,module):
        self.start = 0
        self.end = 0
        self.today = 0
        if self.module is True :
            if str(self.today)>str(self.end):
                self.status = ("completed")
            elif str(self.today) < str(self.start):
                self.status=("upcoming")
            else:
                self.module =("ongoing")
        else:
            print("no module")
      

    def create_student(self):
        LMS.manager[self.mobile] = {}
        LMS.manager[self.mobile][self.password] = self
    def create_module(self):
        LMS.manager[self.module] = {}
# exit = "E"
# while exist:
import json
options = int(input("\n1.Manager. \n2. Student. \n3. Quit\n "))
dict1 = {}
with open("LMS.json","r") as fp:
    dict1 = json.load(fp)
admin=LMS()
student =LMS()
while options < 3 and options > 0:
    if options == 1:
        choice = int(input("1.CRUD operations in Student.\n2. CRUD operations in Modules.\n3. Exit the program"))
        while choice < 3 and choice > 0:
            if choice == 1:
                crud_choice =int(input("For Students\n1. Create.\n2. Read.\n3. Update.\n4. Delete.\n5. Exit ")) 
                if crud_choice < 5  and crud_choice >0:
                    if crud_choice == 1:
                        student =LMS()
                        student.set_name(input("Enter the name of student"))
                        student.set_mobile(input("Enter the mobile number"))
                        student.set_module(input("Enter the module name"))
                        student.set_live_session(input("Enter the livesession"))
                        student.set_period(input("Enter start date"),input("Enter tne end date"))
                        student.set_today(input("Enter today"))
                        student.set_gender(input("Enter the gender"))
                        student.set_email(input("Enter the email"))
                        student.set_age(input("Enter the age"))
                        student.set_password(input("Enter the password")) 
                        admin.status
#                         continue
                        student.create_student()
                        dict1[student.mobile]={}
                        dict1[student.mobile][student.password]=student._dict_
                    elif crud_choice == 2:
                        try:
                            mobile_no = input("Enter the mobile no: ")
                            passw = list(dict1[mobile_no].keys())[0]
                            name = dict1[mobile_no][passw]["name"]
                            mobile = dict1[mobile_no][passw]["mobile"]
                            module = dict1[mobile_no][passw]["module"]
                            live_session = list(dict1[mobile_no][passw]["live_session"])
                            period = dict1[mobile_no][passw]["start"]["end"]
                            today=dict1[moblie_no][passw]["today"]
                            gender = dict1[mobile_no][passw]["gender"]
                            email = dict1[mobile_no][passw]["email"]
                            age =dict2[mobile_no][passw]["age"]
                            print("Name: {}\nMobile_no: {}\nModule: {}\nPeriod : {},{}\nToday: {} \nGender: {}\nEmail: {}\nAge: {}\n".format(name,mobile,module,period,today,gender,email,age))
                        except KeyError:
                            print("the key doesn't exists")
                    elif crud_choice == 3:
                        update_value = int(input("Enter the value which you want to update: n1. Name\n2 Module \n3Email4"))
                        if update_value == 1:
                            mobile_no = input("Enter the mobile no: ")
                            pasword = list(dict1[mobile_no].keys())[0]
                            dict1[mobile_no][pasword]['name']=input("Enter the name: ")
                        elif update_value == 2:
                            mobile_no = input("Enter the mobile no: ")
                            pasword = list(dict1[mobile_no].keys())[0]
                            dict1[mobile_no][pasword]['module']=input("Enter the modlue name: ")
                        elif update_value == 3:
                            mobile_no = input("Enter the mobile no: ")
                            pasword = list(dict1[mobile_no].keys())[0]
                            dict1[mobile_no][pasword]['Email']=input("Enter the email: ")
                            
                    elif crud_choice == 4:
                        try:
                            mobile_no = input("Enter the mobile no: ")
                            del dict1[mobile_no]
                            del LMS.manager[mobile_no]
                        except KeyError:
                            print("the key doesn't exists") 
                    elif crud_choice==5:
                        choice = int(input("1.CRUD operations in Student.\n2. CRUD operations in Modules.\n3. Exit the program"))
                    else:    
                        break
                    
            elif choice == 2:
                crud_choice =int(input("For Modules\n1. Create.\n2. Viewall.\n3. Update.\n4. Delete.\n5. Exit ")) 
                while crud_choice < 5  and crud_choice >0:
                    if crud_choice == 1:
                        admin=LMS()
                        admin.set_module(input("Enter the module name"))
                        admin.set_live_session(input("Enter the livesession"))
                        admin.set_period(input("Enter start date"),input("Enter tne end date"))
                        admin.set_today(input("Enter today"))
                        admin.status
                        admin.create_module()
                        dict1[admin.module]={}
                        
                    elif crud_choice == 2:
                        
                        module_name = input("Enter the module name")
                        
                        live_session = list(dict1[module_name]["live_session"])
                        module = dict1[module_name]["module"]
                        period = dict1[module_name]["start"]["end"]
                        today = dict1[module_name]["today"]
                        print("\nModule: {}\nPeriod : {},{}\nToday: {} \n".format(module,period,today))
                    elif crud_choice == 3:
                        update_value = int(input("Enter the value which you want to update: n1.Module\n2 Period \n3Today"))
                        if update_value == 1:
                            module_name = input("Enter the module_name: ")
                            modules = list(dict1[module].keys())[0]
                            dict1[module_name]['module']=input("Enter the module: ")
                        elif update_value == 2:
                            module_name = input("Enter the module_name: ")
                            period = dict1[module_name]["start"]["end"]
                            dict1[module_name]['Start']["End"]=(input("Enter the start "),input("Enter the End date"))
                        elif update_value == 3:
                            module_name = input("Enter the module_name: ")
                            period = dict1[module_name]["start"]["end"]
                            dict1[module_name]["today"]=input("Enter the today: ")
                            
                    elif crud_choice == 4:
                        module_name = input("Enter the module name: ")
                        del dict1[module_name]
                        del LMS.manager[module_name]
                    else:
                        break
                    crud_choice =int(input("For Modules\n1. Create.\n2. View_All.\3. Update.\n4. Delete.\n5. Exit "))
    elif options ==2:
        pass
    elif options == 3:
        break
    else:
        print("Invalid input try again")
        options = input("1.Manager.\n2 Student.\n3. Quit\n ")
                with open("LMS.json","w") as fp:
        json.dumps(dict1,fp,indent=4)
        1 Manager 
        2 Student 
        3 Quit
                     
                        1 CRUD operations in Student.
                        2 CRUD operations in Modules.
                        3 Exit the program
For Students
1. Create.
2. Read.
3. Update.
4. Delete.
5. Exit 
Enter the name of student
Enter the mobile number
Enter the module name
no module
Enter the livesession
today no session
Enter start date
Enter tne end date
Enter today
no module
Enter the gender
Enter the email
Enter the age
Enter the password
For Students
1. Create.
2. Read.
3. Update.
4. Delete.
5. Exit 
 
 
 
# exit = "E"
# while exist:
import json
options = int(input("1.Manager. \n2. Student. \n3. Quit\n "))
dict1 = {}
with open("LMS.json","r") as fp:
    dict1 = json.load(fp)
while options < 3 and options > 0:
    if options == 1:
        choice = int(input("1.CRUD in Student.\n2. CRUD in Modules.\n3. Eixt"))
        while choice < 3 and choice > 0:
            if choice == 1:
                crud_choice =int(input("For Students\n1. Create.\n2. View_details.\n3. Update.\n4. Delete.\n5. Exit ")) 
                while crud_choice < 5  and crud_choice >0:
                    if crud_choice == 1:
                        student =Edyoda()
                        student.set_name(input("Enter the name of student"))
                        student.set_mobile(input("Enter the mobile number"))
                        student.set_module(input("Enter the module name"))
                        student.set_live_session(input("Enter the livesession"))
                        student.set_period(input("Enter start date"),input("Enter tne end date"))
                        student.set_today(input("Enter today"))
                        student.set_gender(input("Enter the gender"))
                        student.set_email(input("Enter the email"))
                        student.set_age(input("Enter the age"))
                        student.set_password(input("enter password")) 
                        admin.status
                        student.create_student()
                        dict1[student.mobile]={}
                        dict1[student.mobile][student.password]=student._dict_
                    elif crud_choice == 2:
                        try:
                            mobile_no = input("Enter the mobile no: ")
                            pasword = list(dict1[mobile_no].keys())[0]
                            name = dict1[mobile_no][pasword]["name"]
                            mobile = dict1[mobile_no][pasword]["mobile"]
                            module = dict1[mobile_no][pasword]["module"]
    # live_session = list(dict1[mobile_no][pasword]["live_session"])
                            period = dict1[mobile_no][pasword]["start"]["end"]
                            today=deict1[moblie_no][pasword]["today"]
                            gender = dict1[mobile_no][pasword]["gender"]
                            email = dict1[mobile_no][pasword]["email"]
                            age =dict1[mobile_no][pasword]["age"]
                            print("Name: {}\nMobile_no: {}\nModule: {}\nPeriod : {},{}\nToday: {} \nGender: {}\nEmail: {}\nAge: {}\n".format(name,mobile,module,period,today,gender,email,age))
                        except KeyError:
                            print("the key doesn't exists")
                    elif crud_choice == 3:
                        update_value = int(input("Enter the value which you want to update: n1. Name\n2 Module \n3Email4"))
                        if update_value == 1:
                            mobile_no = input("Enter the mobile no: ")
                            pasword = list(dict1[mobile_no].keys())[0]
                            dict1[mobile_no][pasword]['name']=input("Enter the name: ")
                        elif update_value == 2:
                            mobile_no = input("Enter the mobile no: ")
                            pasword = list(dict1[mobile_no].keys())[0]
                            dict1[mobile_no][pasword]['module']=input("Enter the modlue name: ")
                        elif update_value == 3:
                            mobile_no = input("Enter the mobile no: ")
                            pasword = list(dict1[mobile_no].keys())[0]
                            dict1[mobile_no][pasword]['Email']=input("Enter the email: ")
                            
                    elif crud_choice == 4:
                        try:
                            mobile_no = input("Enter the mobile no: ")
                            del dict1[mobile_no]
                            del Edyoda.manager[mobile_no]
                        except KeyError:
                            print("the key doesn't exists") 
                    else:
                        break
                    
            elif choice == 2:
                crud_choice =int(input("For Modules\n1. Create.\n2. Viewall.\3. Update.\n4. Delete.\n5. Exit ")) 
                while crud_choice < 5  and crud_choice >0:
                    if crud_choice == 1:
                        admin =Edyoda()
                        admin.set_module(input("Enter the module name"))
                        admin.set_live_session(input("Enter the livesession"))
                        admin.set_period(input("Enter the start date"),input("Enter the end date"))
                        admin.set_today(input("Enter today's date"))
                        admin.status
                        admin.create_module()
                        dict1[admin.module]={}
                        
                    elif crud_choice == 2:
                        
                        module_name = input("Enter the module name")
                        
                        live_session = list(dict1[mobile_no][pasword]["live_session"])
                        module = dict1[module_name]["module"]
                        period = dict1[module-name]["start"]["end"]
                        today = dict1[module-name]["today"]
                        print("\nModule: {}\nPeriod : {},{}\nToday: {} \n".format(module,period,today))
                    elif cur_choice == 3:
                        update_value = int(input("Enter the value which you want to update: n1.Module\n2 Period \n3Today"))
                        if update_value == 1:
                            module_name = input("Enter the module_name: ")
                            modules = list(dict1[module].keys())[0]
                            dict1[module_name]['module']=input("Enter the module: ")
                        elif update_value == 2:
                            module_name = input("Enter the module_name: ")
                            period = dict1[module_name]["start"]["end"]
                            dict1[module_name]['Start']["End"]=(input("Enter the start "),input("Enter the End date"))
                        elif update_value == 3:
                            module_name = input("Enter the module_name: ")
                            period = dict1[module-name]["start"]["end"]
                            dict1[module_name]["today"]=input("Enter the today: ")
                            
                    elif crud_choice == 4:
                        module_name = input("Enter the module name: ")
                        del dict1[module_name]
                        del Edyoda.manager[module_name]
                    else:
                        break
                    crud_choice =int(input("For Modules\n1. Create.\n2. View_All.\3. Update.\n4. Delete.\n5. Exit "))
    elif options ==2:
        pass
    elif options == 3:
        break
    else:
        print("Invalid input try again")
        options = input("1.Manager.\n2 Student.\n3. Quit\n ")
with open("LMS.json","w") as fp:
    json.dump(dict1,fp,indent=4)
